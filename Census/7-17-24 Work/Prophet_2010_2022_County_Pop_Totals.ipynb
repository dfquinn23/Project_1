# %%
import json
import pandas as pd
import os
import numpy as np
import requests
from dotenv import load_dotenv
import pathlib as path

# %%
load_dotenv()
api_key = os.getenv("CENSUS_API_KEY")

# %%
#2022 County Populations:

state2022_url = f'https://api.census.gov/data/2022/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'
state2022_query = requests.get(state2022_url).json()
#print(json.dumps(state2019_query, indent=4))

# %%
state_pop2022_df = pd.DataFrame(state2022_query)
state_pop2022_df.head()

state_pop2022_df.columns = state_pop2022_df.iloc[0]
state_pop2022_df = state_pop2022_df[1:]
state_pop2022_df.reset_index(drop=True, inplace=True)

state_pop2022_df.head()
state_pop2022_df2 = state_pop2022_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code"})
state_pop2022_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code county
# 0                 Baldwin County, Alabama     246435         01    003
# 19             Tuscaloosa County, Alabama     236780         01    125
# 18              Talladega County, Alabama      80704         01    121
# 17                 Shelby County, Alabama     230115         01    117
# 16              St. Clair County, Alabama      93932         01    115
# ..                                    ...        ...        ...    ...
# 843          Ponce Municipio, Puerto Rico     132138         72    113
# 844       San Juan Municipio, Puerto Rico     334776         72    127
# 845       Toa Alta Municipio, Puerto Rico      66041         72    135
# 846       Toa Baja Municipio, Puerto Rico      72783         72    137
# 847  Trujillo Alto Municipio, Puerto Rico      66810         72    139
#
# [848 rows x 4 columns]

# %%
#2021 County Populations:

state2021_url = f'https://api.census.gov/data/2021/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'
state2021_query = requests.get(state2021_url).json()
#print(json.dumps(state2019_query, indent=4))

# %%
state_pop2021_df = pd.DataFrame(state2021_query)
state_pop2021_df.head()

state_pop2021_df.columns = state_pop2021_df.iloc[0]
state_pop2021_df = state_pop2021_df[1:]
state_pop2021_df.reset_index(drop=True, inplace=True)

state_pop2021_df.head()
state_pop2021_df2 = state_pop2021_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code"})
state_pop2021_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code county
# 0                 Baldwin County, Alabama     239294         01    003
# 19             Tuscaloosa County, Alabama     227007         01    125
# 18              Talladega County, Alabama      81524         01    121
# 17                 Shelby County, Alabama     226902         01    117
# 16              St. Clair County, Alabama      92748         01    115
# ..                                    ...        ...        ...    ...
# 836          Ponce Municipio, Puerto Rico     135084         72    113
# 837       San Juan Municipio, Puerto Rico     337300         72    127
# 838       Toa Alta Municipio, Puerto Rico      67569         72    135
# 839       Toa Baja Municipio, Puerto Rico      74368         72    137
# 840  Trujillo Alto Municipio, Puerto Rico      67211         72    139
#
# [841 rows x 4 columns]

# %%
#2020 County Populations

county2020_query_url = f'https://api.census.gov/data/2020/dec/pl?get=NAME,P1_001N&for=county:*&in=state:*&key={api_key}'

query = requests.get(county2020_query_url).json()
#print(json.dumps(query, indent=4))

# %%
county2020_query_df = pd.DataFrame(query)
county2020_query_df
#column rename

county2020_query_df.columns = county2020_query_df.iloc[0]
county2020_query_df = county2020_query_df[1:]
county2020_query_df.reset_index(drop=True, inplace=True)
county2020_query_df

county2020_query_df2 = county2020_query_df.rename(columns={"NAME": "County", "P1_001N": "Population", "state": "State Code", "county": "County Code"})
county2020_query_df2.sort_values("State Code")
# Out:
# 0                                  County Population State Code County Code
# 0                 Autauga County, Alabama      58805         01         001
# 208            Lauderdale County, Alabama      93564         01         077
# 209                   Lee County, Alabama     174241         01         081
# 210               Lowndes County, Alabama      10311         01         085
# 211                 Macon County, Alabama      19532         01         087
# ...                                   ...        ...        ...         ...
# 1179         Ponce Municipio, Puerto Rico     137491         72         113
# 1180  Quebradillas Municipio, Puerto Rico      23638         72         115
# 1299    Río Grande Municipio, Puerto Rico      47060         72         119
# 1171      Mayagüez Municipio, Puerto Rico      73077         72         097
# 1148        Ciales Municipio, Puerto Rico      16984         72         039
#
# [3221 rows x 4 columns]

# %%
#2019 County Populations:

state2019_url = f'https://api.census.gov/data/2019/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'
state2019_query = requests.get(state2019_url).json()
#print(json.dumps(state2019_query, indent=4))

# %%
state_pop2019_df = pd.DataFrame(state2019_query)
state_pop2019_df.head()

state_pop2019_df.columns = state_pop2019_df.iloc[0]
state_pop2019_df = state_pop2019_df[1:]
state_pop2019_df.reset_index(drop=True, inplace=True)
state_pop2019_df

state_pop2019_df2 = state_pop2019_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2019_df2.sort_values("State Code").head(10)
#query_df.describe()
# Out:
# 0                       County Population State Code County Code
# 0      Baldwin County, Alabama     223234         01         003
# 20      Walker County, Alabama      63521         01         127
# 19  Tuscaloosa County, Alabama     209355         01         125
# 18   Talladega County, Alabama      79978         01         121
# 17      Shelby County, Alabama     217702         01         117
# 16   St. Clair County, Alabama      89512         01         115
# 15      Morgan County, Alabama     119679         01         103
# 14  Montgomery County, Alabama     226486         01         101
# 12    Marshall County, Alabama      96774         01         095
# 11     Madison County, Alabama     372909         01         089

# %%
#2018 County Populations:

state2018_url = f'https://api.census.gov/data/2018/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2018_query = requests.get(state2018_url).json()
#print(json.dumps(state2020_query, indent=4))

# %%
state_pop2018_df = pd.DataFrame(state2018_query)
state_pop2018_df.head()

state_pop2018_df.columns = state_pop2018_df.iloc[0]
state_pop2018_df = state_pop2018_df[1:]
state_pop2018_df.reset_index(drop=True, inplace=True)
state_pop2018_df

state_pop2018_df2 = state_pop2018_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2018_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code County Code
# 0                 Baldwin County, Alabama     218022         01         003
# 20                 Walker County, Alabama      63711         01         127
# 19             Tuscaloosa County, Alabama     208911         01         125
# 18              Talladega County, Alabama      79828         01         121
# 17                 Shelby County, Alabama     215707         01         117
# ..                                    ...        ...        ...         ...
# 833          Ponce Municipio, Puerto Rico     133191         72         113
# 834       San Juan Municipio, Puerto Rico     320967         72         127
# 835       Toa Alta Municipio, Puerto Rico      71094         72         135
# 836       Toa Baja Municipio, Puerto Rico      74623         72         137
# 837  Trujillo Alto Municipio, Puerto Rico      63746         72         139
#
# [838 rows x 4 columns]

# %%
#2017 County Populations:

state2017_url = f'https://api.census.gov/data/2017/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2017_query = requests.get(state2017_url).json()
#print(json.dumps(state2017_query, indent=4))

# %%
state_pop2017_df = pd.DataFrame(state2017_query)
state_pop2017_df.head()

state_pop2017_df.columns = state_pop2017_df.iloc[0]
state_pop2017_df = state_pop2017_df[1:]
state_pop2017_df.reset_index(drop=True, inplace=True)
state_pop2017_df

state_pop2017_df2 = state_pop2017_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2017_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code County Code
# 363               Baldwin County, Alabama     212628         01         003
# 383                Walker County, Alabama      64058         01         127
# 382            Tuscaloosa County, Alabama     207811         01         125
# 381             Talladega County, Alabama      80065         01         121
# 380                Shelby County, Alabama     213605         01         117
# ..                                    ...        ...        ...         ...
# 358          Ponce Municipio, Puerto Rico     140859         72         113
# 359       San Juan Municipio, Puerto Rico     337288         72         127
# 360       Toa Alta Municipio, Puerto Rico      73217         72         135
# 361       Toa Baja Municipio, Puerto Rico      78092         72         137
# 362  Trujillo Alto Municipio, Puerto Rico      66675         72         139
#
# [837 rows x 4 columns]

# %%
#2016 County Populations:

state2016_url = f'https://api.census.gov/data/2016/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2016_query = requests.get(state2016_url).json()
#print(json.dumps(state2016_query, indent=4))

# %%
state_pop2016_df = pd.DataFrame(state2016_query)
state_pop2016_df.head()

state_pop2016_df.columns = state_pop2016_df.iloc[0]
state_pop2016_df = state_pop2016_df[1:]
state_pop2016_df.reset_index(drop=True, inplace=True)
state_pop2016_df

state_pop2016_df2 = state_pop2016_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2016_df2.sort_values("State Code").head(10)
#query_df.describe()
# Out:
# 0                        County Population State Code County Code
# 453      Morgan County, Alabama     119012         01         103
# 458      Walker County, Alabama      64967         01         127
# 457  Tuscaloosa County, Alabama     206102         01         125
# 455      Shelby County, Alabama     210622         01         117
# 454   St. Clair County, Alabama      88019         01         115
# 438     Baldwin County, Alabama     208563         01         003
# 439     Calhoun County, Alabama     114611         01         015
# 440     Cullman County, Alabama      82471         01         043
# 441      DeKalb County, Alabama      70900         01         049
# 442      Elmore County, Alabama      81799         01         051

# %%
#2015 County Populations:

state2015_url = f'https://api.census.gov/data/2015/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2015_query = requests.get(state2015_url).json()
#print(json.dumps(state2015_query, indent=4))

# %%
state_pop2015_df = pd.DataFrame(state2015_query)
state_pop2015_df.head()

state_pop2015_df.columns = state_pop2015_df.iloc[0]
state_pop2015_df = state_pop2015_df[1:]
state_pop2015_df.reset_index(drop=True, inplace=True)
state_pop2015_df

state_pop2015_df2 = state_pop2015_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2015_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                             County Population State Code County Code
# 0            Baldwin County, Alabama     203709         01         003
# 20            Walker County, Alabama      65294         01         127
# 19        Tuscaloosa County, Alabama     203976         01         125
# 18         Talladega County, Alabama      80862         01         121
# 17            Shelby County, Alabama     208713         01         117
# ..                               ...        ...        ...         ...
# 603  Carolina Municipio, Puerto Rico     161884         72         031
# 602    Caguas Municipio, Puerto Rico     134481         72         025
# 600   Arecibo Municipio, Puerto Rico      89648         72         013
# 607  San Juan Municipio, Puerto Rico     355074         72         127
# 601   Bayamón Municipio, Puerto Rico     189159         72         021
#
# [830 rows x 4 columns]

# %%
#2014 County Populations:

state2014_url = f'https://api.census.gov/data/2014/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2014_query = requests.get(state2014_url).json()
#print(json.dumps(state2014_query, indent=4))

# %%
state_pop2014_df = pd.DataFrame(state2014_query)
#state_pop2014_df.head()

state_pop2014_df.columns = state_pop2014_df.iloc[0]
state_pop2014_df = state_pop2014_df[1:]
state_pop2014_df.reset_index(drop=True, inplace=True)
state_pop2014_df

state_pop2014_df2 = state_pop2014_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2014_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code County Code
# 0                 Baldwin County, Alabama     200111         01         003
# 20                 Walker County, Alabama      65471         01         127
# 19             Tuscaloosa County, Alabama     202212         01         125
# 18              Talladega County, Alabama      81322         01         121
# 17                 Shelby County, Alabama     206655         01         117
# ..                                    ...        ...        ...         ...
# 823          Ponce Municipio, Puerto Rico     153540         72         113
# 824       San Juan Municipio, Puerto Rico     365575         72         127
# 825       Toa Alta Municipio, Puerto Rico      74837         72         135
# 826       Toa Baja Municipio, Puerto Rico      84165         72         137
# 827  Trujillo Alto Municipio, Puerto Rico      71019         72         139
#
# [828 rows x 4 columns]

# %%
#2013 County Populations:

state2013_url = f'https://api.census.gov/data/2013/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2013_query = requests.get(state2013_url).json()
#print(json.dumps(state2013_query, indent=4))

# %%
state_pop2013_df = pd.DataFrame(state2013_query)
state_pop2013_df.columns = state_pop2013_df.iloc[0]
state_pop2013_df = state_pop2013_df[1:]
state_pop2013_df.reset_index(drop=True, inplace=True)
state_pop2013_df

state_pop2013_df2 = state_pop2013_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2013_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code County Code
# 0                 Baldwin County, Alabama     195540         01         003
# 20                 Walker County, Alabama      65998         01         127
# 19             Tuscaloosa County, Alabama     200821         01         125
# 18              Talladega County, Alabama      81096         01         121
# 17                 Shelby County, Alabama     204180         01         117
# ..                                    ...        ...        ...         ...
# 823          Ponce Municipio, Puerto Rico     157118         72         113
# 824       San Juan Municipio, Puerto Rico     374682         72         127
# 825       Toa Alta Municipio, Puerto Rico      75292         72         135
# 826       Toa Baja Municipio, Puerto Rico      85971         72         137
# 827  Trujillo Alto Municipio, Puerto Rico      72581         72         139
#
# [828 rows x 4 columns]

# %%
#2012 County Populations:

state2012_url = f'https://api.census.gov/data/2012/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2012_query = requests.get(state2012_url).json()
#print(json.dumps(state2013_query, indent=4))

# %%
state_pop2012_df = pd.DataFrame(state2012_query)
state_pop2012_df.columns = state_pop2012_df.iloc[0]
state_pop2012_df = state_pop2012_df[1:]
state_pop2012_df.reset_index(drop=True, inplace=True)
state_pop2012_df

state_pop2012_df2 = state_pop2012_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2012_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code County Code
# 144                Walker County, Alabama      66221         01         127
# 139                Morgan County, Alabama     120395         01         103
# 138            Montgomery County, Alabama     230149         01         101
# 137                Mobile County, Alabama     413936         01         097
# 136              Marshall County, Alabama      94776         01         095
# ..                                    ...        ...        ...         ...
# 119          Ponce Municipio, Puerto Rico     160322         72         113
# 120       San Juan Municipio, Puerto Rico     382299         72         127
# 121       Toa Alta Municipio, Puerto Rico      75434         72         135
# 122       Toa Baja Municipio, Puerto Rico      87582         72         137
# 123  Trujillo Alto Municipio, Puerto Rico      73718         72         139
#
# [825 rows x 4 columns]

# %%
#2011 County Populations:

state2011_url = f'https://api.census.gov/data/2011/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2011_query = requests.get(state2011_url).json()
#print(json.dumps(state2013_query, indent=4))

# %%
state_pop2011_df = pd.DataFrame(state2011_query)
state_pop2011_df.columns = state_pop2011_df.iloc[0]
state_pop2011_df = state_pop2011_df[1:]
state_pop2011_df.reset_index(drop=True, inplace=True)
state_pop2011_df

state_pop2011_df2 = state_pop2011_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2011_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code County Code
# 131                Mobile County, Alabama     412577         01         097
# 138                Walker County, Alabama      66661         01         127
# 137            Tuscaloosa County, Alabama     197211         01         125
# 136             Talladega County, Alabama      81664         01         121
# 135                Shelby County, Alabama     197936         01         117
# ..                                    ...        ...        ...         ...
# 113          Ponce Municipio, Puerto Rico     163727         72         113
# 114       San Juan Municipio, Puerto Rico     389714         72         127
# 115       Toa Alta Municipio, Puerto Rico      75105         72         135
# 116       Toa Baja Municipio, Puerto Rico      88799         72         137
# 117  Trujillo Alto Municipio, Puerto Rico      74490         72         139
#
# [822 rows x 4 columns]

# %%
#2010 County Populations:

state2010_url = f'https://api.census.gov/data/2010/acs/acs1?get=NAME,B01003_001E&for=county:*&in=state:*&key={api_key}'

state2010_query = requests.get(state2010_url).json()
#print(json.dumps(state2013_query, indent=4))

# %%
state_pop2010_df = pd.DataFrame(state2010_query)
state_pop2010_df.columns = state_pop2010_df.iloc[0]
state_pop2010_df = state_pop2010_df[1:]
state_pop2010_df.reset_index(drop=True, inplace=True)
state_pop2010_df

state_pop2010_df2 = state_pop2010_df.rename(columns={"NAME": "County", "B01003_001E": "Population", "state": "State Code", "county": "County Code"})
state_pop2010_df2.sort_values("State Code")
#query_df.describe()
# Out:
# 0                                  County Population State Code County Code
# 0                 Baldwin County, Alabama     183195         01         003
# 20                 Walker County, Alabama      66947         01         127
# 19             Tuscaloosa County, Alabama     195036         01         125
# 18              Talladega County, Alabama      82110         01         121
# 17                 Shelby County, Alabama     195828         01         117
# ..                                    ...        ...        ...         ...
# 813          Ponce Municipio, Puerto Rico     166164         72         113
# 814       San Juan Municipio, Puerto Rico     395074         72         127
# 815       Toa Alta Municipio, Puerto Rico      73954         72         135
# 816       Toa Baja Municipio, Puerto Rico      89513         72         137
# 817  Trujillo Alto Municipio, Puerto Rico      74754         72         139
#
# [818 rows x 4 columns]

# %%
counties = [state_pop2010_df2, state_pop2011_df2, state_pop2012_df2, 
                    state_pop2013_df2, state_pop2014_df2, state_pop2015_df2, 
                    state_pop2016_df2, state_pop2017_df2, state_pop2018_df2, 
                    state_pop2019_df2, county2020_query_df2, state_pop2021_df2, state_pop2022_df2]

master_county_df = pd.concat(counties, axis=1).dropna()

# Concatenate DataFrames along rows (axis=0) or columns (axis=1)
#master_county_df = pd.concat(dfs, axis=1)  # Use axis=0 for vertical concatenation and axis=1 for horizontal concatenation

master_county_df
# Out:
# 0                                  County Population State Code County Code  \
# 0                 Baldwin County, Alabama     183195         01         003
# 1                 Calhoun County, Alabama     118510         01         015
# 2                 Cullman County, Alabama      80459         01         043
# 3                  DeKalb County, Alabama      71151         01         049
# 4                  Elmore County, Alabama      79549         01         051
# ..                                    ...        ...        ...         ...
# 813          Ponce Municipio, Puerto Rico     166164         72         113
# 814       San Juan Municipio, Puerto Rico     395074         72         127
# 815       Toa Alta Municipio, Puerto Rico      73954         72         135
# 816       Toa Baja Municipio, Puerto Rico      89513         72         137
# 817  Trujillo Alto Municipio, Puerto Rico      74754         72         139
#
# 0                       County Population State Code County Code  \
# 0     Montgomery County, Texas     471734         48         339
# 1    Nacogdoches County, Texas      65466         48         347
# 2         Nueces County, Texas     343281         48         355
# 3         Orange County, Texas      82487         48         361
# 4         Parker County, Texas     118376         48         367
# ..                         ...        ...        ...         ...
# 813      Hidalgo County, Texas     797810         48         215
# 814         Hunt County, Texas      86531         48         231
# 815    Jefferson County, Texas     252802         48         245
# 816      Johnson County, Texas     152734         48         251
# 817      Kaufman County, Texas     105358         48         257
#
# 0                     County Population  ... State Code County Code  \
# 0      Johnson County, Texas     153441  ...         01         001
# 1      Kaufman County, Texas     106753  ...         01         003
# 2      Liberty County, Texas      76571  ...         01         005
# 3      Lubbock County, Texas     285760  ...         01         007
# 4     McLennan County, Texas     238707  ...         01         009
# ..                       ...        ...  ...        ...         ...
# 813  Fort Bend County, Texas     627293  ...         54         081
# 814  Galveston County, Texas     300484  ...         54         083
# 815    Grayson County, Texas     121935  ...         54         085
# 816      Gregg County, Texas     122658  ...         54         087
# 817  Guadalupe County, Texas     139841  ...         54         089
#
# 0                         County Population State Code county  \
# 0        Baldwin County, Alabama     239294         01    003
# 1        Calhoun County, Alabama     115972         01    015
# 2        Cullman County, Alabama      89496         01    043
# 3         DeKalb County, Alabama      71813         01    049
# 4         Elmore County, Alabama      89304         01    051
# ..                           ...        ...        ...    ...
# 813   Marathon County, Wisconsin     137648         55    073
# 814  Milwaukee County, Wisconsin     928059         55    079
# 815  Outagamie County, Wisconsin     191545         55    087
# 816    Ozaukee County, Wisconsin      92497         55    089
# 817    Portage County, Wisconsin      70468         55    097
#
# 0                           County Population State Code county
# 0          Baldwin County, Alabama     246435         01    003
# 1          Calhoun County, Alabama     115788         01    015
# 2          Cullman County, Alabama      90665         01    043
# 3           DeKalb County, Alabama      71998         01    049
# 4           Elmore County, Alabama      89563         01    051
# ..                             ...        ...        ...    ...
# 813        Dodge County, Wisconsin      88282         55    027
# 814   Eau Claire County, Wisconsin     106837         55    035
# 815  Fond du Lac County, Wisconsin     103836         55    039
# 816    Jefferson County, Wisconsin      85784         55    055
# 817      Kenosha County, Wisconsin     167817         55    059
#
# [818 rows x 52 columns]

# %%
#Create initial master df:

masters = [state_pop2010_df2, state_pop2011_df2, state_pop2012_df2, state_pop2013_df2, state_pop2014_df2,
       state_pop2015_df2, state_pop2016_df2, state_pop2017_df2, state_pop2018_df2, state_pop2019_df2,
       county2020_query_df2, state_pop2021_df2, state_pop2022_df2]

# Rename the Population col:

for i, df in enumerate(masters):
    df = df.rename(columns={'Population': f'Pop{i+1}'})
    masters[i] = df[['County', f'Pop{i+1}']]  # Keep only 'name' and renamed population column

# Start with the first DataFrame
master_county_df = masters[0]

# Merged each subsequent DataFrame into the master DataFrame
for df in masters[1:]:
    master_county_df = pd.merge(master_county_df, df, on="County")

master_county_df2 = master_county_df.rename(columns={"Pop1": "2010", "Pop2": "2011", "Pop3": "2012",
                                                     "Pop4": "2013", "Pop5": "2014", "Pop6": "2015",
                                                     "Pop7": "2016", "Pop8": "2017", "Pop9": "2018",
                                                     "Pop10": "2019", "Pop11": "2020", "Pop12": "2021",
                                                     "Pop13": "2022"})

master_county_df2
# Out:
# 0                                  County    2010    2011    2012    2013  \
# 0                 Baldwin County, Alabama  183195  186717  190790  195540
# 1                 Calhoun County, Alabama  118510  117797  117296  116736
# 2                 Cullman County, Alabama   80459   80536   80440   80811
# 3                  DeKalb County, Alabama   71151   71375   71080   71013
# 4                  Elmore County, Alabama   79549   80162   80629   80902
# ..                                    ...     ...     ...     ...     ...
# 794          Ponce Municipio, Puerto Rico  166164  163727  160322  157118
# 795       San Juan Municipio, Puerto Rico  395074  389714  382299  374682
# 796       Toa Alta Municipio, Puerto Rico   73954   75105   75434   75292
# 797       Toa Baja Municipio, Puerto Rico   89513   88799   87582   85971
# 798  Trujillo Alto Municipio, Puerto Rico   74754   74490   73718   72581
#
# 0      2014    2015    2016    2017    2018    2019    2020    2021    2022
# 0    200111  203709  208563  212628  218022  223234  231767  239294  246435
# 1    115916  115620  114611  114728  114277  113605  116441  115972  115788
# 2     81289   82005   82471   82755   83442   83768   87866   89496   90665
# 3     71065   71130   70900   71617   71385   71513   71608   71813   71998
# 4     80977   81468   81799   81677   81887   81209   87977   89304   89563
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 794  153540  149028  145278  140859  133191  131881  137491  135084  132138
# 795  365575  355074  347052  337288  320967  318441  342259  337300  334776
# 796   74837   74368   73980   73217   71094   72025   66852   67569   66041
# 797   84165   82065   80207   78092   74623   74271   75293   74368   72783
# 798   71019   69615   68242   66675   63746   63674   67740   67211   66810
#
# [799 rows x 14 columns]

# %%
master_county_df2.astype({"2010":int, "2011":int, "2012":int, "2013":int, "2014":int, "2015":int, "2016":int, "2017":int,
                           "2018":int, "2019":int, "2020":int, "2021":int, "2022":int})
# Out:
# 0                                  County    2010    2011    2012    2013  \
# 0                 Baldwin County, Alabama  183195  186717  190790  195540
# 1                 Calhoun County, Alabama  118510  117797  117296  116736
# 2                 Cullman County, Alabama   80459   80536   80440   80811
# 3                  DeKalb County, Alabama   71151   71375   71080   71013
# 4                  Elmore County, Alabama   79549   80162   80629   80902
# ..                                    ...     ...     ...     ...     ...
# 794          Ponce Municipio, Puerto Rico  166164  163727  160322  157118
# 795       San Juan Municipio, Puerto Rico  395074  389714  382299  374682
# 796       Toa Alta Municipio, Puerto Rico   73954   75105   75434   75292
# 797       Toa Baja Municipio, Puerto Rico   89513   88799   87582   85971
# 798  Trujillo Alto Municipio, Puerto Rico   74754   74490   73718   72581
#
# 0      2014    2015    2016    2017    2018    2019    2020    2021    2022
# 0    200111  203709  208563  212628  218022  223234  231767  239294  246435
# 1    115916  115620  114611  114728  114277  113605  116441  115972  115788
# 2     81289   82005   82471   82755   83442   83768   87866   89496   90665
# 3     71065   71130   70900   71617   71385   71513   71608   71813   71998
# 4     80977   81468   81799   81677   81887   81209   87977   89304   89563
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 794  153540  149028  145278  140859  133191  131881  137491  135084  132138
# 795  365575  355074  347052  337288  320967  318441  342259  337300  334776
# 796   74837   74368   73980   73217   71094   72025   66852   67569   66041
# 797   84165   82065   80207   78092   74623   74271   75293   74368   72783
# 798   71019   69615   68242   66675   63746   63674   67740   67211   66810
#
# [799 rows x 14 columns]

# %%
#CAGR / Total Growth addition - FINAL DF:

master_county_df2.to_csv("C:/Users/Daniel Quinn/Desktop/Bootcamp/Project_1_Working_Copy/Census/7-17-24 Work/master_county_df2.csv")

final_county_df = pd.read_csv("C:/Users/Daniel Quinn/Desktop/Bootcamp/Project_1_Working_Copy/Census/7-17-24 Work/master_county_df2.csv")

#final_county_df = pd.DataFrame(final_county_df)

final_county_df2 = final_county_df[["County", "2010", "2011", "2012",
                                   "2013", "2014", "2015", "2016", "2017",
                                    "2018", "2019", "2020", "2021", "2022"]]

final_county_df2['Total % Change'] = final_county_df2['2022'] / final_county_df2['2010']-1

def calculate_cagr(start_value, end_value, periods):
    return (end_value / start_value) ** (1 / periods) - 1

# Calculate the number of periods
start_year = 2010
end_year = 2022
periods = end_year - start_year

# Calculate CAGR for each row
final_county_df2['CAGR'] = final_county_df2.apply(lambda row: calculate_cagr(row[str(start_year)], row[str(end_year)], periods), axis=1)

final_county_df2.columns
# Out:
# Index(['County', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', 'Total % Change',
#        'CAGR'],
#       dtype='object')

# %%
#For the Prophet Analysis:

final_county_df3 = final_county_df2
del final_county_df3['CAGR']
del final_county_df3['Total % Change']
final_county_df3
# Out:
#                                    County    2010    2011    2012    2013  \
# 0                 Baldwin County, Alabama  183195  186717  190790  195540
# 1                 Calhoun County, Alabama  118510  117797  117296  116736
# 2                 Cullman County, Alabama   80459   80536   80440   80811
# 3                  DeKalb County, Alabama   71151   71375   71080   71013
# 4                  Elmore County, Alabama   79549   80162   80629   80902
# ..                                    ...     ...     ...     ...     ...
# 794          Ponce Municipio, Puerto Rico  166164  163727  160322  157118
# 795       San Juan Municipio, Puerto Rico  395074  389714  382299  374682
# 796       Toa Alta Municipio, Puerto Rico   73954   75105   75434   75292
# 797       Toa Baja Municipio, Puerto Rico   89513   88799   87582   85971
# 798  Trujillo Alto Municipio, Puerto Rico   74754   74490   73718   72581
#
#        2014    2015    2016    2017    2018    2019    2020    2021    2022
# 0    200111  203709  208563  212628  218022  223234  231767  239294  246435
# 1    115916  115620  114611  114728  114277  113605  116441  115972  115788
# 2     81289   82005   82471   82755   83442   83768   87866   89496   90665
# 3     71065   71130   70900   71617   71385   71513   71608   71813   71998
# 4     80977   81468   81799   81677   81887   81209   87977   89304   89563
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 794  153540  149028  145278  140859  133191  131881  137491  135084  132138
# 795  365575  355074  347052  337288  320967  318441  342259  337300  334776
# 796   74837   74368   73980   73217   71094   72025   66852   67569   66041
# 797   84165   82065   80207   78092   74623   74271   75293   74368   72783
# 798   71019   69615   68242   66675   63746   63674   67740   67211   66810
#
# [799 rows x 14 columns]

# %%
prophet_csv_file = final_county_df3.transpose()
prophet_csv_file
# Out:
#                             0                        1    \
# County  Baldwin County, Alabama  Calhoun County, Alabama
# 2010                     183195                   118510
# 2011                     186717                   117797
# 2012                     190790                   117296
# 2013                     195540                   116736
# 2014                     200111                   115916
# 2015                     203709                   115620
# 2016                     208563                   114611
# 2017                     212628                   114728
# 2018                     218022                   114277
# 2019                     223234                   113605
# 2020                     231767                   116441
# 2021                     239294                   115972
# 2022                     246435                   115788
#
#                             2                       3    \
# County  Cullman County, Alabama  DeKalb County, Alabama
# 2010                      80459                   71151
# 2011                      80536                   71375
# 2012                      80440                   71080
# 2013                      80811                   71013
# 2014                      81289                   71065
# 2015                      82005                   71130
# 2016                      82471                   70900
# 2017                      82755                   71617
# 2018                      83442                   71385
# 2019                      83768                   71513
# 2020                      87866                   71608
# 2021                      89496                   71813
# 2022                      90665                   71998
#
#                            4                       5    \
# County  Elmore County, Alabama  Etowah County, Alabama
# 2010                     79549                  104462
# 2011                     80162                  104303
# 2012                     80629                  104392
# 2013                     80902                  103931
# 2014                     80977                  103531
# 2015                     81468                  103057
# 2016                     81799                  102564
# 2017                     81677                  102755
# 2018                     81887                  102501
# 2019                     81209                  102268
# 2020                     87977                  103436
# 2021                     89304                  103162
# 2022                     89563                  103088
#
#                             6                          7    \
# County  Houston County, Alabama  Jefferson County, Alabama
# 2010                     101888                     658555
# 2011                     102369                     658931
# 2012                     103402                     660009
# 2013                     103668                     659479
# 2014                     104193                     660793
# 2015                     104173                     660367
# 2016                     104056                     659521
# 2017                     104346                     659197
# 2018                     104722                     659300
# 2019                     105882                     658573
# 2020                     107202                     674721
# 2021                     107458                     667820
# 2022                     108079                     665409
#
#                                8                    9    ...  \
# County  Lauderdale County, Alabama  Lee County, Alabama  ...
# 2010                         92679               140780  ...
# 2011                         92781               143468  ...
# 2012                         92542               147257  ...
# 2013                         92797               150933  ...
# 2014                         93096               154255  ...
# 2015                         92596               156993  ...
# 2016                         92318               158991  ...
# 2017                         92538               161604  ...
# 2018                         92387               163941  ...
# 2019                         92729               164542  ...
# 2020                         93564               174241  ...
# 2021                         94043               177218  ...
# 2022                         95878               180773  ...
#
#                                    789                            790  \
# County  Bayamón Municipio, Puerto Rico  Caguas Municipio, Puerto Rico
# 2010                            207960                         142749
# 2011                            205693                         142678
# 2012                            202325                         141392
# 2013                            198958                         139559
# 2014                            194210                         137032
# 2015                            189159                         134481
# 2016                            184374                         132164
# 2017                            179565                         129604
# 2018                            170480                         124434
# 2019                            169269                         124606
# 2020                            185187                         127244
# 2021                            182673                         126756
# 2022                            181577                         125136
#
#                                     791                              792  \
# County  Carolina Municipio, Puerto Rico  Guaynabo Municipio, Puerto Rico
# 2010                             176633                            97864
# 2011                             175129                            97280
# 2012                             172728                            96226
# 2013                             169597                            94645
# 2014                             165820                            92799
# 2015                             161884                            90879
# 2016                             158457                            89307
# 2017                             154489                            87328
# 2018                             147661                            83787
# 2019                             146984                            83728
# 2020                             154815                            89780
# 2021                             152993                            89195
# 2022                             151571                            89057
#
#                                     793                           794  \
# County  Mayagüez Municipio, Puerto Rico  Ponce Municipio, Puerto Rico
# 2010                              89028                        166164
# 2011                              87712                        163727
# 2012                              86034                        160322
# 2013                              84170                        157118
# 2014                              81915                        153540
# 2015                              79510                        149028
# 2016                              77748                        145278
# 2017                              75525                        140859
# 2018                              71986                        133191
# 2019                              71530                        131881
# 2020                              73077                        137491
# 2021                              71939                        135084
# 2022                              70609                        132138
#
#                                     795                              796  \
# County  San Juan Municipio, Puerto Rico  Toa Alta Municipio, Puerto Rico
# 2010                             395074                            73954
# 2011                             389714                            75105
# 2012                             382299                            75434
# 2013                             374682                            75292
# 2014                             365575                            74837
# 2015                             355074                            74368
# 2016                             347052                            73980
# 2017                             337288                            73217
# 2018                             320967                            71094
# 2019                             318441                            72025
# 2020                             342259                            66852
# 2021                             337300                            67569
# 2022                             334776                            66041
#
#                                     797                                   798
# County  Toa Baja Municipio, Puerto Rico  Trujillo Alto Municipio, Puerto Rico
# 2010                              89513                                 74754
# 2011                              88799                                 74490
# 2012                              87582                                 73718
# 2013                              85971                                 72581
# 2014                              84165                                 71019
# 2015                              82065                                 69615
# 2016                              80207                                 68242
# 2017                              78092                                 66675
# 2018                              74623                                 63746
# 2019                              74271                                 63674
# 2020                              75293                                 67740
# 2021                              74368                                 67211
# 2022                              72783                                 66810
#
# [14 rows x 799 columns]

# %%
prophet_csv_file.to_csv("C:/Users/Daniel Quinn/Desktop/Bootcamp/Project_1_Working_Copy/Census/7-17-24 Work/2010_2022_County_Pop_for_Prophet.csv")

# %%
import datetime as dt
from prophet import Prophet

# %matplotlib inline

# %%
hourly_prices = pd.read_csv(
    "C:/Users/Daniel Quinn/Desktop/Bootcamp/Project_1_Working_Copy/Census/7-17-24 Work/2010_2022_County_Pop_for_Prophet.csv",
    index_col='County',
    parse_dates=True,
    infer_datetime_format=True
).dropna()

# Display the first and last five rows of the DataFrame
display(hourly_prices.head())
display(hourly_prices.tail())
# Out:
# C:\Users\Daniel Quinn\AppData\Local\Temp\ipykernel_20292\2035072436.py:1: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   hourly_prices = pd.read_csv(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 hourly_prices = pd.read_csv(
#       2     "C:/Users/Daniel Quinn/Desktop/Bootcamp/Project_1_Working_Copy/Census/7-17-24 Work/2010_2022_County_Pop_for_Prophet.csv",
#       3     index_col='County',
#       4     parse_dates=True,
#       5     infer_datetime_format=True
#       6 ).dropna()
#       8 # Display the first and last five rows of the DataFrame
#       9 display(hourly_prices.head())
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:162, in CParserWrapper.__init__(self, src, **kwds)
#     160 # error: Cannot determine type of 'names'
#     161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
# --> 162 self._set_noconvert_columns()
#     164 # error: Cannot determine type of 'names'
#     165 self.orig_names = self.names  # type: ignore[has-type]
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:215, in CParserWrapper._set_noconvert_columns(self)
#     213 col_indices = [names_dict[x] for x in self.names]  # type: ignore[has-type]
#     214 # error: Cannot determine type of 'names'
# --> 215 noconvert_columns = self._set_noconvert_dtype_columns(
#     216     col_indices,
#     217     self.names,  # type: ignore[has-type]
#     218 )
#     219 for col in noconvert_columns:
#     220     self._reader.set_noconvert(col)
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\base_parser.py:664, in ParserBase._set_noconvert_dtype_columns(self, col_indices, names)
#     662 if isinstance(self.index_col, list):
#     663     for k in self.index_col:
# --> 664         noconvert_columns.add(_set(k))
#     665 elif self.index_col is not None:
#     666     noconvert_columns.add(_set(self.index_col))
#
# File c:\Users\Daniel Quinn\anaconda3\envs\dev\lib\site-packages\pandas\io\parsers\base_parser.py:641, in ParserBase._set_noconvert_dtype_columns.<locals>._set(x)
#     638     x = usecols[x]
#     640 if not is_integer(x):
# --> 641     x = col_indices[names.index(x)]
#     643 return x
#
# ValueError: 'County' is not in list
